# %%
from getpass import getpass
token = getpass()

# !git clone https://{token}@github.com/Mar-SHieee/Enterprise-AI-Data-Analyst.git
# Out:
# ··········
# fatal: destination path 'Enterprise-AI-Data-Analyst' already exists and is not an empty directory.

# %%
# %cd /content/Enterprise-AI-Data-Analyst
# !ls
# Out:
# /content/Enterprise-AI-Data-Analyst
# app   models	 rag	    reports	      spark  src
# data  notebooks  README.md  requirements.txt  sql    tests
